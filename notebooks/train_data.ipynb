# %%
import pandas as pd

data = pd.read_csv('/home/serao/violence_detection/violence-detection/log/optflow/version_0/metrics.csv')
validation = data[['epoch','val_loss', 'val_acc']].dropna()
validation = validation.astype({'epoch':int})
validation.set_index('epoch', inplace=True)
train = data[['epoch','train_loss', 'train_acc']].dropna()
train = train.astype({'epoch':int})
train.set_index('epoch', inplace=True)
log = train.join(validation, on='epoch')
log
# Out:
#        train_loss  train_acc  val_loss   val_acc
# epoch
# 0        0.691132   0.535714  0.657950  0.603741
# 1        0.633508   0.655248  0.618058  0.651361
# 2        0.594459   0.697522  0.596736  0.687075
# 3        0.565088   0.715743  0.600291  0.656463
# 4        0.546853   0.728863  0.579608  0.700680
# 5        0.525271   0.733236  0.574796  0.709184
# 6        0.487194   0.771137  0.571348  0.710884
# 7        0.464633   0.787172  0.564513  0.727891
# 8        0.422848   0.814140  0.569778  0.724490
# 9        0.403306   0.827259  0.574040  0.714286
# 10       0.372158   0.856414  0.593143  0.727891
# 11       0.339587   0.877551  0.579390  0.715986
# 12       0.290906   0.905977  0.600263  0.712585
# 13       0.289883   0.886297  0.602169  0.719388
# 14       0.245490   0.911808  0.633385  0.721088
# 15       0.243375   0.907434  0.641732  0.709184

# %%
from matplotlib import pyplot as plt

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,6))

log[['train_acc', 'val_acc']].plot(ax=axes[0])
axes[0].set_title('accuracy')
log[['train_loss', 'val_loss']].plot(ax=axes[1])
axes[1].set_title('loss')
# Out:
# Text(0.5, 1.0, 'loss')
