# %%
import pandas as pd

data = pd.read_csv('/home/serao/violence_detection/violence-detection/log/contro_test/version_2/metrics.csv')
validation = data[['epoch','val_loss', 'val_acc']].dropna()
validation = validation.astype({'epoch':int})
validation.set_index('epoch', inplace=True)
train = data[['epoch','train_loss', 'train_acc']].dropna()
train = train.astype({'epoch':int})
train.set_index('epoch', inplace=True)
log = train.join(validation, on='epoch')
log
# Out:
#        train_loss  train_acc  val_loss   val_acc
# epoch
# 0        0.590237   0.732031  0.425108  0.890625
# 1        0.421564   0.847656  0.277359  0.921875
# 2        0.333971   0.885156  0.211153  0.928125
# 3        0.285974   0.893750  0.165565  0.946875
# 4        0.258717   0.910937  0.143430  0.965625
# 5        0.247744   0.900000  0.127139  0.959375
# 6        0.199720   0.932031  0.120610  0.959375
# 7        0.209021   0.919531  0.105101  0.962500
# 8        0.190611   0.931250  0.101314  0.968750
# 9        0.189481   0.924219  0.094750  0.978125
# 10       0.182631   0.928906  0.086611  0.981250
# 11       0.163926   0.937500  0.096810  0.971875
# 12       0.168701   0.930469  0.078153  0.987500
# 13       0.145290   0.946875  0.084501  0.984375
# 14       0.154243   0.946094  0.077856  0.984375
# 15       0.148701   0.945312  0.067174  0.984375
# 16       0.103243   0.967969  0.076906  0.987500
# 17       0.143359   0.950781  0.072963  0.981250
# 18       0.118700   0.956250  0.072498  0.987500
# 19       0.121342   0.956250  0.088051  0.975000
# 20       0.116504   0.957031  0.065590  0.984375
# 21       0.115704   0.955469  0.071723  0.987500
# 22       0.101328   0.965625  0.067111  0.984375
# 23       0.084596   0.973437  0.068829  0.990625
# 24       0.093687   0.970312  0.063828  0.990625
# 25       0.089455   0.969531  0.063595  0.981250
# 26       0.098087   0.960938  0.060272  0.987500
# 27       0.092202   0.967188  0.068510  0.978125
# 28       0.091209   0.971094  0.068861  0.981250
# 29       0.100254   0.957031  0.074502  0.987500
# 30       0.073622   0.977344  0.067868  0.987500
# 31       0.085788   0.968750  0.078952  0.984375
# 32       0.078513   0.967188  0.066613  0.990625
# 33       0.087951   0.967188  0.062883  0.993750
# 34       0.085026   0.969531  0.061540  0.993750
# 35       0.067651   0.972656  0.079250  0.990625
# 36       0.057451   0.980469  0.091825  0.981250
# 37       0.056680   0.982813  0.067193  0.990625
# 38       0.096848   0.951563  0.074963  0.984375
# 39       0.070950   0.969531  0.062808  0.990625
# 40       0.059650   0.978125  0.065859  0.990625
# 41       0.081242   0.964063  0.092576  0.984375
# 42       0.082110   0.964063  0.068681  0.990625
# 43       0.056205   0.980469  0.072347  0.987500
# 44       0.072437   0.969531  0.061784  0.990625
# 45       0.069130   0.972656  0.069617  0.990625
# 46       0.062493   0.975000  0.073685  0.987500
# 47       0.069410   0.967969  0.064457  0.993750
# 48       0.051246   0.983594  0.065250  0.987500

# %%
from matplotlib import pyplot as plt
import seaborn as sns

sns.set_style("darkgrid")
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20,6))

log[['train_acc', 'val_acc']].plot(ax=axes[0])
axes[0].set_title('accuracy')
log[['train_loss', 'val_loss']].plot(ax=axes[1])
axes[1].set_title('loss')
# Out:
# Text(0.5, 1.0, 'loss')
